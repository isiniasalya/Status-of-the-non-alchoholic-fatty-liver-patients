# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'D:\UOC1\4\ST 4052\DAP 1\DTATA\\nafld1.csv')
df2 = pd.read_csv(r'C:\Users\sahan\4yr sem 1\merged_dataset.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
liver = df
liver.head()
# Out:
#    Unnamed: 0  id  age  male  weight  height        bmi  case.id  futime  \
# 0        3631   1   57     0    60.0   163.0  22.690939  10630.0    6261
# 1        8458   2   67     0    70.4   168.0  24.884028  14817.0     624
# 2        6298   3   53     1   105.8   186.0  30.453537      3.0    1783
# 3       15398   4   56     1   109.3   170.0  37.830100   6628.0    3143
# 4       13261   5   68     1     NaN     NaN        NaN   1871.0    1836
#
#    status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
liver.columns
# Out:
# Index(['Unnamed: 0', 'id', 'age', 'male', 'weight', 'height', 'bmi', 'case.id',
#        'futime', 'status'],
#       dtype='object')

# %%
liver.rename(columns={'Unnamed: 0':'Un', 'male':'gender','weight':'weight_kg','height':'height_cm'}, inplace = True)
liver.head()
# Out:
#       Un  id  age  gender  weight_kg  height_cm        bmi  case.id  futime  \
# 0   3631   1   57       0       60.0      163.0  22.690939  10630.0    6261
# 1   8458   2   67       0       70.4      168.0  24.884028  14817.0     624
# 2   6298   3   53       1      105.8      186.0  30.453537      3.0    1783
# 3  15398   4   56       1      109.3      170.0  37.830100   6628.0    3143
# 4  13261   5   68       1        NaN        NaN        NaN   1871.0    1836
#
#    status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
liver.columns
# Out:
# Index(['Un', 'id', 'age', 'gender', 'weight_kg', 'height_cm', 'bmi', 'case.id',
#        'futime', 'status'],
#       dtype='object')

# %%
df = liver.drop(["Un","case.id"],axis=1)
df.head()
# Out:
#    id  age  gender  weight_kg  height_cm        bmi  futime  status
# 0   1   57       0       60.0      163.0  22.690939    6261       0
# 1   2   67       0       70.4      168.0  24.884028     624       0
# 2   3   53       1      105.8      186.0  30.453537    1783       0
# 3   4   56       1      109.3      170.0  37.830100    3143       0
# 4   5   68       1        NaN        NaN        NaN    1836       1

# %%
df.shape
# Out:
# (17549, 8)

# %%
df2.shape
# Out:
# (15204, 7)

# %%
#Merging 2 datasets
common_ids = set(df['id']).intersection(set(df2['id']))

# %%
df_filtered = df[df['id'].isin(common_ids)]

# %%
merged_df = df_filtered.merge(df2, on='id', how='inner')

# %% [raw]
# merged_df.tail(10)

# %%
merged_df.tail(10)
# Out:
#           id  age  gender  weight_kg  height_cm        bmi  futime  status  \
# 15194  17555   68       1       75.0      170.0  25.951557    1280       0
# 15195  17556   53       0      123.2      172.0  41.393446    1124       0
# 15196  17557   46       1       72.6      167.0  26.013913    1364       0
# 15197  17558   72       0      106.8      168.0  38.035584    3991       1
# 15198  17559   62       1      120.0      185.0  35.062089     470       0
# 15199  17560   56       0       84.6      159.0  33.296128     628       0
# 15200  17562   46       0       53.0      161.0  20.501023    1894       0
# 15201  17563   52       1      111.8      154.0  47.335905    3841       0
# 15202  17564   59       0       57.3        NaN        NaN    5081       0
# 15203  17566   69       1       94.1      180.0  29.204650    2744       0
#
#        avg_pre_hdl  avg_post_hdl  avg_total_hdl  avg_pre_chol  avg_post_chol  \
# 15194    40.000000     42.000000      41.000000     40.000000      42.000000
# 15195    44.600000           NaN      44.600000     44.600000            NaN
# 15196    48.500000     55.333333      52.600000     48.500000      55.333333
# 15197    62.000000     68.000000      67.076923     62.000000      68.000000
# 15198    48.000000           NaN      48.000000     48.000000            NaN
# 15199    43.750000           NaN      43.750000     43.750000            NaN
# 15200    55.333333     86.000000      63.000000     55.333333      86.000000
# 15201    35.058824     34.894737      34.972222     35.058824      34.894737
# 15202    54.600000           NaN      54.600000     54.600000            NaN
# 15203    39.000000     44.125000      41.562500     39.000000      44.125000
#
#        avg_total_chol
# 15194       41.000000
# 15195       44.600000
# 15196       52.600000
# 15197       67.076923
# 15198       48.000000
# 15199       43.750000
# 15200       63.000000
# 15201       34.972222
# 15202       54.600000
# 15203       41.562500

# %%
df = merged_df
df.head()
# Out:
#    id  age  gender  weight_kg  height_cm        bmi  futime  status  \
# 0   1   57       0       60.0      163.0  22.690939    6261       0
# 1   2   67       0       70.4      168.0  24.884028     624       0
# 2   3   53       1      105.8      186.0  30.453537    1783       0
# 3   4   56       1      109.3      170.0  37.830100    3143       0
# 4   5   68       1        NaN        NaN        NaN    1836       1
#
#    avg_pre_hdl  avg_post_hdl  avg_total_hdl  avg_pre_chol  avg_post_chol  \
# 0    75.000000     66.750000      68.400000     75.000000      66.750000
# 1    74.166667           NaN      74.166667     74.166667            NaN
# 2    55.666667           NaN      55.666667     55.666667            NaN
# 3    48.714286     36.222222      41.687500     48.714286      36.222222
# 4    45.500000     44.000000      45.000000     45.500000      44.000000
#
#    avg_total_chol
# 0       68.400000
# 1       74.166667
# 2       55.666667
# 3       41.687500
# 4       45.000000

# %%
df.shape
# Out:
# (15204, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15204 entries, 0 to 15203
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              15204 non-null  int64
#  1   age             15204 non-null  int64
#  2   gender          15204 non-null  int64
#  3   weight_kg       12125 non-null  float64
#  4   height_cm       13586 non-null  float64
#  5   bmi             12027 non-null  float64
#  6   futime          15204 non-null  int64
#  7   status          15204 non-null  int64
#  8   avg_pre_hdl     13985 non-null  float64
#  9   avg_post_hdl    12762 non-null  float64
#  10  avg_total_hdl   15204 non-null  float64
#  11  avg_pre_chol    13985 non-null  float64
#  12  avg_post_chol   12762 non-null  float64
#  13  avg_total_chol  15204 non-null  float64
# dtypes: float64(9), int64(5)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                  id           age        gender     weight_kg     height_cm  \
# count  15204.000000  15204.000000  15204.000000  12125.000000  13586.000000
# mean    8792.231123     53.760260      0.457840     86.751348    169.385102
# std     5061.277621     14.114116      0.498236     22.280495     10.121147
# min        1.000000     18.000000      0.000000     33.400000    123.000000
# 25%     4418.750000     44.000000      0.000000     70.500000    162.000000
# 50%     8804.000000     53.000000      0.000000     84.200000    169.000000
# 75%    13159.250000     64.000000      1.000000     99.700000    177.000000
# max    17566.000000     98.000000      1.000000    181.700000    215.000000
#
#                 bmi        futime       status   avg_pre_hdl  avg_post_hdl  \
# count  12027.000000  15204.000000  15204.00000  13985.000000  12762.000000
# mean      30.210779   2448.695409      0.07748     52.243175     53.348922
# std        7.098583   1561.566587      0.26736     14.888351     17.057529
# min        9.207332      7.000000      0.00000      3.000000     13.000000
# 25%       25.246400   1180.000000      0.00000     41.500000     41.000000
# 50%       29.017523   2197.500000      0.00000     49.900000     50.125000
# 75%       33.890430   3388.250000      0.00000     60.750000     62.611538
# max       84.395725   7245.000000      1.00000    179.800000    190.000000
#
#        avg_total_hdl  avg_pre_chol  avg_post_chol  avg_total_chol
# count   15204.000000  13985.000000   12762.000000    15204.000000
# mean       52.713798     52.243175      53.348922       52.713798
# std        15.206297     14.888351      17.057529       15.206297
# min         3.000000      3.000000      13.000000        3.000000
# 25%        41.666667     41.500000      41.000000       41.666667
# 50%        50.200000     49.900000      50.125000       50.200000
# 75%        61.333333     60.750000      62.611538       61.333333
# max       165.777778    179.800000     190.000000      165.777778

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# gender               0
# weight_kg         3079
# height_cm         1618
# bmi               3177
# futime               0
# status               0
# avg_pre_hdl       1219
# avg_post_hdl      2442
# avg_total_hdl        0
# avg_pre_chol      1219
# avg_post_chol     2442
# avg_total_chol       0
# dtype: int64

# %%
#Handling missing values of height, weight and BMI
df["gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['gender'] = df['gender'].replace([0,1],['female','male'])
df.head(2)
# Out:
#    id  age  gender  weight_kg  height_cm        bmi  futime  status  \
# 0   1   57  female       60.0      163.0  22.690939    6261       0
# 1   2   67  female       70.4      168.0  24.884028     624       0
#
#    avg_pre_hdl  avg_post_hdl  avg_total_hdl  avg_pre_chol  avg_post_chol  \
# 0    75.000000         66.75      68.400000     75.000000          66.75
# 1    74.166667           NaN      74.166667     74.166667            NaN
#
#    avg_total_chol
# 0       68.400000
# 1       74.166667

# %%
sns.histplot(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()

# %%
sns.scatterplot(x='age', y='weight_kg', data=df)
plt.xlabel('Age')
plt.ylabel('Weight')
plt.title('Scatter Plot: Age vs. Weight')
plt.show()
#Hence it concludes that there is no relationship of age and weight

# %%
ax = sns.countplot(x='gender',data=df)
total = len(df)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, height + 3, f'{height / total * 100:.1f}%', ha="center")
    
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar Plot: Gender Counts and Percentages')
plt.show()

# %%
sns.boxplot(x='gender', y='weight_kg', data=df)
plt.xlabel('Gender')
plt.ylabel('Weight')
plt.title('Box Plot: Gender vs. Weight')
plt.show()
#Therefore, we can see that there is a relationship between gender and the weight

# %%
sns.boxplot(x='gender', y='height_cm', data=df)
plt.xlabel('Gender')
plt.ylabel('Height')
plt.title('Box Plot: Gender vs. Height')
plt.show()
#Hence there is a relationship between height and gender

# %%
df['weight_kg'] = df.groupby('gender', group_keys=False)['weight_kg'].apply(lambda x: x.fillna(x.mean())).reset_index(drop=True)
df['height_cm'] = df.groupby('gender', group_keys=False)['height_cm'].apply(lambda x: x.fillna(x.mean())).reset_index(drop=True)
df['bmi'] = df.apply(lambda row: row['weight_kg'] / ((row['height_cm'] / 100) ** 2) if pd.isna(row['bmi']) else row['bmi'], axis=1)

# %%
df.head() #End solving missing values of weight, height and BMI
# Out:
#    id  age  gender   weight_kg   height_cm        bmi  futime  status  \
# 0   1   57  female   60.000000  163.000000  22.690939    6261       0
# 1   2   67  female   70.400000  168.000000  24.884028     624       0
# 2   3   53    male  105.800000  186.000000  30.453537    1783       0
# 3   4   56    male  109.300000  170.000000  37.830100    3143       0
# 4   5   68    male   95.303713  177.094254  30.387914    1836       1
#
#    avg_pre_hdl  avg_post_hdl  avg_total_hdl  avg_pre_chol  avg_post_chol  \
# 0    75.000000     66.750000      68.400000     75.000000      66.750000
# 1    74.166667           NaN      74.166667     74.166667            NaN
# 2    55.666667           NaN      55.666667     55.666667            NaN
# 3    48.714286     36.222222      41.687500     48.714286      36.222222
# 4    45.500000     44.000000      45.000000     45.500000      44.000000
#
#    avg_total_chol
# 0       68.400000
# 1       74.166667
# 2       55.666667
# 3       41.687500
# 4       45.000000

# %%
a = sns.displot(df, x="weight_kg", bins=15, kde=True, hue='gender', element="step")

a.fig.set_dpi(100)
a.fig.suptitle("Weight distribution", y = 1.02, size = 15)
plt.xlabel('Weight', fontsize = 12)
plt.ylabel('Count', fontsize = 12)
plt.xticks(rotation=20)

plt.show()

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# gender               0
# weight_kg            0
# height_cm            0
# bmi                  0
# futime               0
# status               0
# avg_pre_hdl       1219
# avg_post_hdl      2442
# avg_total_hdl        0
# avg_pre_chol      1219
# avg_post_chol     2442
# avg_total_chol       0
# dtype: int64

# %%
#Now handling the missing values of pre and post hdl and chol values
columns_to_check = ['avg_pre_hdl', 'avg_post_hdl', 'avg_pre_chol', 'avg_post_chol']
df_dropped_missing = df.dropna(subset=columns_to_check)

# %%
df_dropped_missing.isnull().sum()
# Out:
# id                0
# age               0
# gender            0
# weight_kg         0
# height_cm         0
# bmi               0
# futime            0
# status            0
# avg_pre_hdl       0
# avg_post_hdl      0
# avg_total_hdl     0
# avg_pre_chol      0
# avg_post_chol     0
# avg_total_chol    0
# dtype: int64

# %%
df = df_dropped_missing
df.shape
# Out:
# (11543, 14)

# %%
df.head()
# Out:
#    id  age  gender   weight_kg   height_cm        bmi  futime  status  \
# 0   1   57  female   60.000000  163.000000  22.690939    6261       0
# 3   4   56    male  109.300000  170.000000  37.830100    3143       0
# 4   5   68    male   95.303713  177.094254  30.387914    1836       1
# 5   6   39  female   63.900000  155.000000  26.615590    1581       0
# 6   7   49  female   66.200000  161.000000  25.519339    3109       0
#
#    avg_pre_hdl  avg_post_hdl  avg_total_hdl  avg_pre_chol  avg_post_chol  \
# 0    75.000000     66.750000      68.400000     75.000000      66.750000
# 3    48.714286     36.222222      41.687500     48.714286      36.222222
# 4    45.500000     44.000000      45.000000     45.500000      44.000000
# 5    50.000000     69.000000      57.600000     50.000000      69.000000
# 6    61.444444     77.583333      70.666667     61.444444      77.583333
#
#    avg_total_chol
# 0       68.400000
# 3       41.687500
# 4       45.000000
# 5       57.600000
# 6       70.666667

# %%
#Correaltion Analysis
corr=df.corr()
plt.subplots(figsize=(20,15))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True),vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
bx = sns.countplot(x='status',data=df)
total = len(df)
for p in bx.patches:
    height = p.get_height()
    percentage = f'{100 * height / total:.1f}%'
    bx.annotate(percentage, (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom')
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Bar Plot: Status Counts and Percentages')
plt.show()

# %% [markdown]
# n

# %%
sns.boxplot(data=df, x='status', y='avg_pre_hdl')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_pre_hdl')
# Out:
# Text(0, 0.5, 'avg_pre_hdl')

# %%
sns.boxplot(data=df, x='status', y='avg_post_hdl')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_post_hdl')
# Out:
# Text(0, 0.5, 'avg_post_hdl')

# %%
sns.boxplot(data=df, x='status', y='avg_total_hdl')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_total_hdl')
# Out:
# Text(0, 0.5, 'avg_total_hdl')

# %%
sns.boxplot(data=df, x='status', y='avg_pre_chol')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_pre_chol')
# Out:
# Text(0, 0.5, 'avg_pre_chol')

# %%
sns.boxplot(data=df, x='status', y='avg_post_chol')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_post_chol')
# Out:
# Text(0, 0.5, 'avg_post_chol')

# %%
sns.boxplot(data=df, x='status', y='avg_total_chol')
plt.title('NEW')
plt.xlabel('Status')
plt.ylabel('avg_total_chol')
# Out:
# Text(0, 0.5, 'avg_total_chol')

# %%
df = pd.get_dummies(df, columns = ['gender'])

# %%
df
df.to_csv('alldata.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error

# %%
#define predictor and response variables
X = df[["age","gender_male","gender_female","weight_kg","height_cm","bmi","futime","avg_pre_hdl","avg_post_hdl","avg_total_hdl","avg_pre_chol","avg_post_chol","avg_total_chol"]]
y = df[['status']]

#define cross-validation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

mse = []
n = len(X)

# Calculate MSE with only the intercept
score = -1*model_selection.cross_val_score(PLSRegression(n_components=1),
           np.ones((n,1)), y, cv=cv, scoring='neg_mean_squared_error').mean()    
mse.append(score)

# Calculate MSE using cross-validation, adding one component at a time
for i in np.arange(1, 6):
    pls = PLSRegression(n_components=i)
    score = -1*model_selection.cross_val_score(pls, scale(X), y, cv=cv,
               scoring='neg_mean_squared_error').mean()
    mse.append(score)

#plot test MSE vs. number of components
plt.plot(mse)
plt.xlabel('Number of PLS Components')
plt.ylabel('MSE')
plt.title('hp')
# Out:
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:93: RuntimeWarning: invalid value encountered in true_divide
#   y_weights = np.dot(Y.T, x_score) / np.dot(x_score.T, x_score)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:325: RuntimeWarning: invalid value encountered in true_divide
#   x_loadings = np.dot(x_scores, Xk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\cross_decomposition\_pls.py:334: RuntimeWarning: invalid value encountered in true_divide
#   y_loadings = np.dot(x_scores, Yk) / np.dot(x_scores, x_scores)
# C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 103, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 438, in mean_squared_error
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 96, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 800, in check_array
#     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#   File "C:\Users\sahan\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 114, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn(
# Text(0.5, 1.0, 'hp')

# %%
#split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1) 

#calculate RMSE
pls = PLSRegression(n_components=2)
pls.fit(scale(X_train), y_train)

np.sqrt(mean_squared_error(y_test, pls.predict(scale(X_test))))
# Out:
# 0.2410064478769398

# %%
dftrain = pd.concat([X_train,y_train], axis=1)
dftrain.to_csv('train1.csv')
dftest = pd.concat([X_test,y_test], axis=1)
dftest.to_csv('test1.csv')

# %%
y_train
# Out:
#        status
# 10299       0
# 5065        0
# 4450        0
# 11812       0
# 2118        0
# ...       ...
# 10272       0
# 14427       0
# 1159        0
# 6808        0
# 291         0
#
# [8080 rows x 1 columns]

# %%
x=pls.x_scores_[:,0]
y=pls.x_scores_[:,1]
scores = pd. DataFrame(pls.x_scores_, columns=['x', 'y'])
z=y_train['status']
#scores_with_status=pd.concat([scores,z], axis=1)
scores_with_status=pd.concat([scores.reset_index(drop=True),z.reset_index(drop=True)], axis=1)

# %%
scores_with_status
# Out:
#              x         y  status
# 0     0.442310  3.666989       0
# 1     2.175376 -0.760430       0
# 2     0.741244 -0.993105       0
# 3    -2.970226  2.688987       0
# 4     1.989207  1.145936       0
# ...        ...       ...     ...
# 8075 -2.255254  1.644278       0
# 8076  0.282416 -2.441944       0
# 8077 -1.374646 -1.537762       0
# 8078  0.282155 -3.767745       0
# 8079  0.594774  0.352408       0
#
# [8080 rows x 3 columns]

# %%
import seaborn
plt.figure(figsize=(10,6),dpi=300)
seaborn.set(style='whitegrid')
fmri = seaborn.load_dataset("fmri")
 
chart=seaborn.scatterplot(x="x",
                    y="y",
                    hue="status",
                    data=scores_with_status)
chart.set_title('PLSR Scores Plot', fontdict={'size': 17, 'weight': 'bold'})
chart.set_xlabel('PLSR Component 1', fontdict={'size': 15})
chart.set_ylabel('PLSR Component 2', fontdict={'size': 15})
plt.savefig('scores.png',dpi=300)
plt.show()

# %%
scores_with_status.isnull().sum()
# Out:
# x         0
# y         0
# status    0
# dtype: int64

# %%
plt.scatter(x, y)
plt.xlabel("PLSR Component 1")
plt.ylabel("PLSR Component 2")
plt.title("PLSR Scores Plot")
# Out:
# Text(0.5, 1.0, 'PLSR Scores Plot')

# %%
loadings = pls.x_loadings_
loadings1= pls.y_loadings_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 loadings = pls.x_loadings_
#       2 loadings1= pls.y_loadings_
#
# NameError: name 'pls' is not defined

# %%
plt.figure(figsize=(5,5),dpi=300)
plt.rcParams.update({'font.size': 6})
plt.scatter(loadings[:, 0], loadings[:, 1])
plt.scatter(loadings1[:, 0], loadings1[:, 1])
for i, feature_name in enumerate(X_train.columns):
    plt.annotate(feature_name, (loadings[i, 0], loadings[i, 1]),rotation=20)
for i, feature_name in enumerate(y_train.columns):
    plt.annotate(feature_name, (loadings1[i, 0], loadings1[i, 1]),rotation=10)    
plt.xlabel('PLSR Component 1')
plt.ylabel('PLSR Component 2')
plt.savefig('loadings.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
#get the scores of the first two components
scores = pls.x_scores_[:,:2]

# calculate the total variance of the input data
total_variance = np.var(X_train, axis=0).sum()

# calculate the total variance of the scores
scores_variance = np.var(scores, axis=0).sum()
scores_variance

#calculate the proportion of variance explained by the first two components
variance_explained = scores_variance/ total_variance

variance_explained*100
# Out:
# 0.00027551751880961536

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import r2_score

def pls_explained_variance(pls, X, Y_true, do_plot=True):
    r2 = np.zeros(pls.n_components)
    x_transformed = pls.transform(X) # Project X into low dimensional basis
    for i in range(0, pls.n_components):
        Y_pred = (np.dot(x_transformed[:, i][:, np.newaxis],
                         pls.y_loadings_[:, i][:, np.newaxis].T) * pls._y_std   
                  + pls._y_mean)
        r2[i] = r2_score(Y_true, Y_pred)
        overall_r2 = r2_score(Y_true, pls.predict(X))  # Use all components together.

    if do_plot:
        component = np.arange(pls.n_components) + 1
        plt.plot(component, r2, '.-')
        plt.xticks(component)
        plt.xlabel('PLS Component #'), plt.ylabel('r2')
        plt.title(f'Summed individual r2: {np.sum(r2):.3f}, '
                  f'Overall r2: {overall_r2:.3f}')
        plt.show()

    return r2, overall_r2

# Example usage.
pls = PLSRegression(n_components=3).fit(X_train, y_train)
pls_explained_variance(pls, X_test, y_test)
# Out:
# (array([0.05957942, 0.01891456, 0.000952  ]), 0.07974674674292948)

# %%
# Import the required libraries
from sklearn.cross_decomposition import PLSRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Create and fit the PLS-DA model
plsda = PLSRegression(n_components=2)
plsda.fit(X_train, y_train)

# Make predictions on the test set
y_pred = plsda.predict(X_test)

# Convert predictions to class labels
y_pred_labels = [1 if p > 0.5 else 0 for p in y_pred]

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred_labels)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9324285301761478
